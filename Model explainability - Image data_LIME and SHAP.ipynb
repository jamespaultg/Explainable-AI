# %% [markdown]
# # LIME (Local Interpretable Model-Agnostic Explanations)

# %% [markdown]
# ## Can LIME be used on an Image Classification model?
# Credits: https://www.dlology.com/blog/can-you-trust-keras-to-tell-african-from-asian-elephant/

# %% [markdown]
# Here is a simpler example of the use of LIME for image classification by using Keras (v2 or greater)

# %%
# quietly install the required packages
# !pip install -r requirements.txt --quiet
# Out:
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import os
import keras
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
print('Notebook run using keras:', keras.__version__)
# Out:
# Notebook run using keras: 2.3.1

# %% [markdown]
# # Using Inception
# Here we create a standard InceptionV3 pretrained model and use it on images by first preprocessing them with the preprocessing tools.
# If you are interested, you can also check out other pre-trained models(with weights) on ImageNet available in the Keras library here(https://keras.io/applications/)
#
# Human readable list of the 1000 classes from Imagenet https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a

# %% [markdown]
# ## An idea to change it
# race car (751)
# sports car (817)
# https://europeluxurycars.com/luxuria/exotic-cars/difference-between-race-cars-vs-sports-cars

# %%
inet_model = inc_net.InceptionV3()

# %%
def transform_img_fn(path_list):
    out = []
    for img_path in path_list:
        img = image.load_img(img_path, target_size=(299, 299))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = inc_net.preprocess_input(x)
        out.append(x)
    return np.vstack(out)

# %% [markdown]
# ## Let's see the top 5 prediction for some image

# %%
images = transform_img_fn([os.path.join('data','asian-african-elephants.jpg')])
# I'm dividing by 2 and adding 0.5 because of how this Inception represents images
plt.imshow(images[0] / 2 + 0.5)
preds = inet_model.predict(images)
for x in decode_predictions(preds)[0]:
    print(x)
# Out:
# ('n02504013', 'Indian_elephant', 0.9683746)
# ('n02504458', 'African_elephant', 0.017002005)
# ('n01871265', 'tusker', 0.003533841)
# ('n06359193', 'web_site', 0.0007669757)
# ('n01694178', 'African_chameleon', 0.000364892)

# %%
#The model.predict function will output probabilities for each class indexes ranging from 0~999.
# And the LIME explainer need to know which class by class index we want an explanation.

from keras.utils import get_file
import json

def get_class_index(name):
    """Get the index of a item in ImageNet model."""

    name = name.lower()
    fpath = get_file('imagenet_class_index.json',
                     'https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json',
                     cache_subdir='models',
                     file_hash='c2c37ea517e94d9795004a39431a14cb')
    with open(fpath) as f:
        classes = json.load(f)
    for k, v in classes.items():
        if v[1].lower() == name:
            return int(k)
    return None

Indian_elephant = get_class_index("Indian_elephant")
African_elephant = get_class_index("African_elephant")

# %% [markdown]
# ## Explanation
# Now let's get an explanation

# %%
# %load_ext autoreload
# %autoreload 2
import os,sys
try:
    import lime
except:
    sys.path.append(os.path.join('..', '..')) # add the current directory
    import lime
from lime import lime_image

explainer = lime_image.LimeImageExplainer()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# hide_color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels. Here, we set it to 0 (in the representation used by inception model, 0 means gray)

# %%
# %%time
# Hide color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
explanation = explainer.explain_instance(images[0], inet_model.predict, 
                                         top_labels=5, 
                                         hide_color=0, 
                                         num_samples=1000)
# Out:
# 100% |########################################################################|
# CPU times: user 11min 20s, sys: 51.8 s, total: 12min 12s
# Wall time: 58.3 s

# %% [markdown]
# Image classifiers are a bit slow. Notice that an explanation on my Surface Book dGPU took 1min 29s

# %% [markdown]
# ### Now let's see the explanation for the top class (Indian_elephant and African_elephant)

# %% [markdown]
# We can see the top 5 superpixels that are most positive towards the class with the rest of the image hidden

# %%
from skimage.segmentation import mark_boundaries

# %%
temp, mask = explanation.get_image_and_mask(Indian_elephant, positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
temp, mask = explanation.get_image_and_mask(African_elephant, positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# Or with the rest of the image present:
# ```python
# hide_rest=False
# ```

# %%
temp, mask = explanation.get_image_and_mask(Indian_elephant, positive_only=True, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# We can also see the 'pros and cons' (pros in green, cons in red)

# %%
temp, mask = explanation.get_image_and_mask(Indian_elephant, positive_only=False, num_features=10, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# Or the pros and cons that have weight at least 0.1

# %%
temp, mask = explanation.get_image_and_mask(Indian_elephant, positive_only=False, num_features=1000, hide_rest=False, min_weight=0.1)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
# !pip install shap --quiet
# Out:
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import shap #SHAP package

# %% [markdown]
# ## Where can I find more resources?
#
# - Link to the original LIME paper 'Why should I trust you' - https://arxiv.org/abs/1602.04938
# - Github link : https://github.com/marcotcr/lime
#
# - https://www.oreilly.com/learning/introduction-to-local-interpretable-model-agnostic-explanations-lime
